# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import datetime
from bson import ObjectId
from pymongo import MongoClient

# %%
client = MongoClient('127.0.0.1', 27017)
db = client.moniter_crowdfunding
db.authenticate(name="worker", password="hard", mechanism="SCRAM-SHA-1")
s_project = db.success_projects
project = db.projects
f_project = db.failure_projects

# %%
db.list_collection_names()
# Out:
# ['projects', 'success_projects', 'founders', 'failure_projects', 'front_page']

# %%
db.founders.count_documents({})
# Out:
# 6092

# %%
s_project.count_documents({})
# Out:
# 4160

# %%
f_project.count_documents({})
# Out:
# 3040

# %%
project.count_documents({'状态': '众筹成功'})
# Out:
# 133

# %%
project.count_documents({'状态': '众筹中'})
# Out:
# 95

# %%
s_project.find_one({},
                   projection={'项目动态信息': False, '各档动态信息': False, '评论': False}, 
                   sort=[('状态变换时间0-1', -1)])
# Out:
# {'_id': '1840697979',
#  '状态': '项目成功',
#  '状态变换时间0-1': datetime.datetime(2020, 7, 10, 18, 0, 4, 211000),
#  '爬取次数': 81,
#  '众筹期限': 20,
#  '公司名称': '松原市扶余市中泽航森信息技术咨询有限公司',
#  '公司地址': '吉林松原市\xa0\xa0松原市扶余市三岔河镇恒信阳光北岸小区22号楼5号门',
#  '公司工作时间': '周一至周日 09:00-21:00',
#  '公司电话': '15801606302',
#  '发起人名称': 'xfx0456',
#  '发起人链接': '/funderCenter.action?flag=2&id=1840697979',
#  '各档基础信息': {},
#  '所属类别': '食品',
#  '目标金额': 2000,
#  '项目名称': '花生助农进行时',
#  '状态变换时间1-2': datetime.datetime(2020, 7, 11, 12, 0, 4, 542000),
#  '状态变换时间2-3': datetime.datetime(2020, 7, 31, 12, 0, 4, 111000),
#  '状态变换时间3-4': datetime.datetime(2020, 8, 15, 6, 0, 3, 697000)}

# %%
f_project.find_one({}, projection={'项目动态信息': False, '各档动态信息': False, '评论': False})
# Out:
# {'_id': '101445',
#  '状态': '众筹中',
#  '状态变换时间0-1': datetime.datetime(2019, 3, 13, 12, 0, 3, 512000),
#  '爬取次数': 189,
#  '众筹期限': 45,
#  '公司名称': '上海事万文化传播有限公司',
#  '公司地址': '上海闵行区七宝镇\xa0\xa0黎明花园51号102',
#  '公司工作时间': '周一至周日 09:00-20:00',
#  '公司电话': '18801904219',
#  '发起人名称': '壹隅君',
#  '发起人链接': '/funderCenter.action?flag=2&id=101445',
#  '各档基础信息': {},
#  '所属类别': '图书',
#  '目标金额': 100000,
#  '项目名称': '《在这世界的角落》原著漫画',
#  '状态变换时间1-2': datetime.datetime(2019, 3, 16, 0, 0, 4, 254000),
#  'transfer_time': datetime.datetime(2019, 10, 8, 12, 53, 29, 735000)}

# %%
db.founders.find_one({'_id': '1840697979'})

# %% [markdown]
# # 一、处理众筹成功项目

# %% [markdown]
# 将累计动态数据转换为间隔时间段数据

# %%
def increment(x):
    return [(x[i] - x[i-1]) if i >= 1 else x[0] for i in range(len(x))]

# %% [markdown]
# - 项目描述性信息

# %%
def description(item):
    start_time = item['状态变换时间1-2']
    end_time = item['状态变换时间2-3']

    print(f"项目编号: {item['_id']}\n项目名称: {item['项目名称']}\n所属类别: {item['所属类别']}\n公司名称: {item['公司名称']}")
    print(f"\n众筹期限: {item['众筹期限']}\n项目状态: {item['状态']}")
    print()
    print("发起人页面:", f"http://z.jd.com/project/details/{item['_id']}.html") 
    print("项目页面:", f"http://z.jd.com{item['发起人链接']}")
    print()
    print('预热中:', item['状态变换时间0-1'].strftime('%Y年%m月%d日 %H:%M:%S'), sep='\t') 
    print('预热中->众筹中:', start_time.strftime('%Y年%m月%d日 %H:%M:%S'), sep='\t')
    print('众筹中->众筹成功:', end_time.strftime('%Y年%m月%d日 %H:%M:%S'), sep='\t')
    print('众筹中->项目成功:', item['状态变换时间3-4'].strftime('%Y年%m月%d日 %H:%M:%S'), sep='\t')

# %% [markdown]
# - 按照项目更新时间将项目动态信息转换为`pd.DataFrame()`

# %%
def to_df(item):
    dyn_info = item['项目动态信息']
    t_fund = item['目标金额']
    start_t = item['状态变换时间1-2']  # 众筹开始时间
    end_t = item['状态变换时间2-3']  # 众筹成功时间
    # 更加网所示的更新时间去除重复
    a1 = dyn_info[0]
    records = {'更新时间':[], '支持者数':[], '关注数':[], '点赞数':[], '完成百分比':[], '筹集金额':[]}
    for i, a2 in enumerate(dyn_info):
        if a2["更新时间"] != a1['更新时间']:
            records['更新时间'].append(a2['更新时间'])
            records['支持者数'].append(a2['支持者数'])
            records['关注数'].append(a2['关注数'])
            records['完成百分比'].append(a2['完成百分比'])
            records['筹集金额'].append(a2['筹集金额'])
            records['点赞数'].append(a2['点赞数'])
            a1 = a2
    # 绘图
    col_names = ['关注数', '支持者数', '点赞数', '完成百分比', '筹集金额']
    df = pd.DataFrame(records, index=records['更新时间'], columns=col_names)
    return df

# %% [markdown]
# - 转换为每天的增长数

# %%
def transfer_to_day(df):
    new_index = []
    for i, index in enumerate(df.index):
        if i == 0:
            a = df.index[i]
        else:
            b = df.index[i]
            a = df.index[i - 1]
            if (b.year, b.month, b.day) != (a.year, a.month, a.day):
                new_index.append(i-1)
    
    return df.iloc[new_index]

# %% [markdown]
# - 判断是否有邻居效应
# > - 利用Bass模型与线性模型分别拟合：比较两种模型拟合的$r^2$
# > - 如果有邻居影响，则进一步分析潜在影响网络的结构

# %%
proj = s_project.find_one()

# %%
proj.keys()
# Out:
# dict_keys(['_id', '各档动态信息', '众筹期限', '公司地址', '项目动态信息', '状态变换时间1-2', '各档基础信息', '爬取次数', '项目名称', '所属类别', '状态', '公司电话', '状态变换时间0-1', '目标金额', '发起人链接', '公司工作时间', '公司名称', '发起人名称', '评论', '状态变换时间2-3', '状态变换时间3-4'])

# %%
proj["所属类别"]
# Out:
# '原创设计'

# %%
proj['评论']['评论详细']
# Out:
# {'1938346': {'topicId': 1938346,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_1cf1413ff9c6aa23de06f3be6e234929881c359206d041af489a82d99c7c3efb',
#   'day': 157,
#   'hour': 3771,
#   'min': 226277,
#   'replys': 1,
#   'topicContent': '鞋子收到了，不错的做工，设计风格可以。还会出新款吗？怎么继续关注到你们呢？',
#   'createTime': '2018-07-05 11:22:42',
#   'updateTime': '2018-07-05 11:27:30',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_6b1388',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3662313338386332346437633931353236303931323135303039_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2113684,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1938346,
#      'parentId': 0,
#      'content': '谢谢您的认可和支持，LOKY专注原创设计，欢迎添加微信 xhtf28  备注鞋子，入群交流，继续关注我们',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-07-05 11:27:30',
#      'updateTime': '2018-07-05 11:27:30',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 157,
#      'hour': 3771,
#      'min': 226273,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1911685': {'topicId': 1911685,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_1801950f2782571ee5934ec27fafc705',
#   'day': 188,
#   'hour': 4529,
#   'min': 271783,
#   'replys': 1,
#   'topicContent': '为什么橡胶很薄，且不是覆盖全部鞋底？中间不拍踩到尖锐的东西吗？',
#   'createTime': '2018-06-03 20:57:06',
#   'updateTime': '2018-06-04 10:35:02',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '枯荣928',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/bfddc8d939323831353132323234323430383630_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2078081,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1911685,
#      'parentId': 0,
#      'content': '耐磨橡胶片发泡EVA组合，6CM加厚鞋底，对于高度不满足可选择增高2CM,不会薄的呢，欢迎添加微信 xhtf28 备注鞋子，入群讨论，看实物图哦',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-06-04 10:35:02',
#      'updateTime': '2018-06-04 10:35:02',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 188,
#      'hour': 4516,
#      'min': 270965,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1906209': {'topicId': 1906209,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_4a303115b34a27df2917779dc9c6333e',
#   'day': 194,
#   'hour': 4660,
#   'min': 279620,
#   'replys': 1,
#   'topicContent': '19885961588367已经支持  希望不压脚背就好',
#   'createTime': '2018-05-29 10:19:49',
#   'updateTime': '2018-05-29 11:04:45',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '大妹孒',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/77644e43486e6b664a58687773777931353432313632333936373339_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2070117,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1906209,
#      'parentId': 0,
#      'content': '感谢支持，不会压脚背的呢。对于做鞋，痴迷的陈老师有足够的数据和实践经验，设计合理，舒适不压脚，而且支持7天无理由退换，无忧担心。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-29 11:04:45',
#      'updateTime': '2018-05-29 11:04:45',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 194,
#      'hour': 4659,
#      'min': 279575,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1905648': {'topicId': 1905648,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_ae31f26fb7e4f65698943f8a5c61ba51',
#   'day': 194,
#   'hour': 4677,
#   'min': 280677,
#   'replys': 1,
#   'topicContent': '订单号19786402619736,大概什么时候能发货啊！等待好漫长啊\n[大哭]',
#   'createTime': '2018-05-28 16:43:10',
#   'updateTime': '2018-05-28 16:59:32',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '原始天',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/77616e676e616e3230303831343834303130363938373338_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2069328,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1905648,
#      'parentId': 0,
#      'content': '感谢您的支持和等待，项目众筹中，待项目进度达150%或结束后，将尽快安排发货，欢迎添加微信号：xhtf28 备注鞋子 入群交流',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-28 16:59:32',
#      'updateTime': '2018-05-28 16:59:32',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 194,
#      'hour': 4677,
#      'min': 280661,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1905472': {'topicId': 1905472,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_7f6cad90e4fea9d07648839d410d3cd4881c359206d041af489a82d99c7c3efb',
#   'day': 194,
#   'hour': 4679,
#   'min': 280782,
#   'replys': 1,
#   'topicContent': '考虑了很久 女朋友说蓝色不错 果断拍了双蓝色 不错可以再给她买一双希望尽快发货',
#   'createTime': '2018-05-28 14:58:11',
#   'updateTime': '2018-05-28 15:19:52',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jll云',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3665646232333133663964366431353334383232313638313837_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2069133,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1905472,
#      'parentId': 0,
#      'content': '喜欢就买，对自己好一点，选择毫不犹豫，相信到手后，您会选择给女票来双的',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-28 15:19:52',
#      'updateTime': '2018-05-28 15:19:52',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 194,
#      'hour': 4679,
#      'min': 280760,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1902381': {'topicId': 1902381,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_6d667f7fdb361af20666d0197cc5a89e881c359206d041af489a82d99c7c3efb',
#   'day': 198,
#   'hour': 4756,
#   'min': 285369,
#   'replys': 1,
#   'topicContent': '19885805680321枣红，40麻烦不要发错货',
#   'createTime': '2018-05-25 10:31:21',
#   'updateTime': '2018-05-25 10:54:10',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '大佬大林仔',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3734316437323235623261613631353237363439363734323134_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2065290,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1902381,
#      'parentId': 0,
#      'content': '好哒，亲亲，感谢您对二十年经验的手工匠人LOKY的支持',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-25 10:54:10',
#      'updateTime': '2018-05-25 10:54:10',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 198,
#      'hour': 4755,
#      'min': 285346,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1899408': {'topicId': 1899408,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_c57df1069685b3529a2d3ff658c67896881c359206d041af489a82d99c7c3efb',
#   'day': 200,
#   'hour': 4822,
#   'min': 289320,
#   'replys': 2,
#   'topicContent': '订单号19951137725046   选了42码，换41码',
#   'createTime': '2018-05-22 16:39:58',
#   'updateTime': '2018-05-28 22:59:28',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_135556kkm',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2070116,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1899408,
#      'parentId': 2069642,
#      'content': 'OK',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-29 11:03:17',
#      'updateTime': '2018-05-29 11:03:17',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 194,
#      'hour': 4659,
#      'min': 279577,
#      'levelId': 0,
#      'repnicknameShow': 'jd_135556kkm',
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2069642,
#      'pin': '_c57df1069685b3529a2d3ff658c67896881c359206d041af489a82d99c7c3efb',
#      'topicId': 1899408,
#      'parentId': 0,
#      'content': '我要的是灰色，不要发错哦',
#      'replys': 1,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-28 22:59:28',
#      'updateTime': '2018-05-29 11:03:17',
#      'nicknameShow': 'jd_135556kkm',
#      'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#      'day': 194,
#      'hour': 4671,
#      'min': 280301,
#      'levelId': 3,
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2061244,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1899408,
#      'parentId': 0,
#      'content': '好哒，收到！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-22 16:55:57',
#      'updateTime': '2018-05-22 16:55:57',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 200,
#      'hour': 4821,
#      'min': 289304,
#      'levelId': 0,
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 3},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1897366': {'topicId': 1897366,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_c57df1069685b3529a2d3ff658c67896881c359206d041af489a82d99c7c3efb',
#   'day': 202,
#   'hour': 4867,
#   'min': 292042,
#   'replys': 4,
#   'topicContent': '我的码数选大了，可以帮我换小一码吗\n',
#   'createTime': '2018-05-20 19:18:16',
#   'updateTime': '2018-05-22 15:13:14',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_135556kkm',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2061066,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1897366,
#      'parentId': 2061016,
#      'content': '是的呢，您找不到您的订单号吗？在京东金融APP--我--订单  查看，或者联系客服：0760-87826716',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-22 15:37:33',
#      'updateTime': '2018-05-22 15:37:33',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 200,
#      'hour': 4823,
#      'min': 289382,
#      'levelId': 0,
#      'repnicknameShow': 'jd_135556kkm',
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2061016,
#      'pin': '_c57df1069685b3529a2d3ff658c67896881c359206d041af489a82d99c7c3efb',
#      'topicId': 1897366,
#      'parentId': 0,
#      'content': '话题区是不是在这里',
#      'replys': 1,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-22 15:13:14',
#      'updateTime': '2018-05-22 15:37:33',
#      'nicknameShow': 'jd_135556kkm',
#      'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#      'day': 200,
#      'hour': 4823,
#      'min': 289407,
#      'levelId': 3,
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2059084,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1897366,
#      'parentId': 2058962,
#      'content': '1.在话题区提供订单号，和需要更改的尺码。2.联系客服：0760-87826716，说明需要更改信息。只要联系上我们都可以的呢',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-21 13:59:33',
#      'updateTime': '2018-05-21 13:59:33',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 202,
#      'hour': 4848,
#      'min': 290920,
#      'levelId': 0,
#      'repnicknameShow': 'jd_135556kkm',
#      'parentPin': 'jd_54101b24581cc',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 2,
#    'allCount': 6},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1897264': {'topicId': 1897264,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_c57df1069685b3529a2d3ff658c67896881c359206d041af489a82d99c7c3efb',
#   'day': 202,
#   'hour': 4869,
#   'min': 292195,
#   'replys': 1,
#   'topicContent': '我平时穿运动鞋42码，我看评论这个鞋标准码偏大，那我买了42码怎么办[大哭][大哭][大哭]',
#   'createTime': '2018-05-20 16:45:07',
#   'updateTime': '2018-05-21 09:30:39',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_135556kkm',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2058505,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1897264,
#      'parentId': 0,
#      'content': '您可以申请了在重新拍，或可以提供订单号和需要改的码数',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-21 09:30:39',
#      'updateTime': '2018-05-21 09:30:39',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 202,
#      'hour': 4853,
#      'min': 291189,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1896118': {'topicId': 1896118,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_f435d2fa922921ef633204878f682473881c359206d041af489a82d99c7c3efb',
#   'day': 204,
#   'hour': 4899,
#   'min': 293998,
#   'replys': 1,
#   'topicContent': '订单19885977623299  买了一鞋和另拍了鞋垫',
#   'createTime': '2018-05-19 10:42:13',
#   'updateTime': '2018-05-19 11:10:23',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'kim_大忙人',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3136386136396263636232353831353233313734363933393133_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2056650,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1896118,
#      'parentId': 0,
#      'content': '好的，感谢支持原创，让你个性百搭，不撞鞋，酷一整夏',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-19 11:10:23',
#      'updateTime': '2018-05-19 11:10:23',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 204,
#      'hour': 4899,
#      'min': 293970,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1893986': {'topicId': 1893986,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_4a303115b34a27df2917779dc9c6333e',
#   'day': 206,
#   'hour': 4944,
#   'min': 296662,
#   'replys': 2,
#   'topicContent': '鞋子怕压脚背呢',
#   'createTime': '2018-05-17 14:18:11',
#   'updateTime': '2018-05-17 14:35:35',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '大妹孒',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/77644e43486e6b664a58687773777931353432313632333936373339_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2054106,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1893986,
#      'parentId': 0,
#      'content': '欢迎可以进群大家一起交流，添加微信号xhtf28 备注鞋子',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-17 14:35:35',
#      'updateTime': '2018-05-17 14:35:35',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 206,
#      'hour': 4944,
#      'min': 296644,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2054102,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1893986,
#      'parentId': 0,
#      'content': '不会压脚背的呢。对于做鞋，痴迷的陈老师有足够的数据和实践经验，设计合理，舒适不压脚，而且支持7天无理由退换，无忧担心。[玫瑰]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-17 14:34:39',
#      'updateTime': '2018-05-17 14:34:39',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 206,
#      'hour': 4944,
#      'min': 296645,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 2},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1892604': {'topicId': 1892604,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_7f6cad90e4fea9d07648839d410d3cd4881c359206d041af489a82d99c7c3efb',
#   'day': 207,
#   'hour': 4972,
#   'min': 298343,
#   'replys': 1,
#   'topicContent': '问下买过的朋友  会有色差吗 、颜色会不会太亮',
#   'createTime': '2018-05-16 10:17:32',
#   'updateTime': '2018-05-16 10:37:41',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jll云',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3665646232333133663964366431353334383232313638313837_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2052325,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1892604,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，之前的鞋友，对我们LOKY的匠心精神一度认可的，追求完美，照片均会因灯光问题，显示器等视觉上不同，实物拍摄的 色差小 ， 欢迎可以进群大家一起交流，看实物图哦，添加微信号xhtf28   备注鞋子',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-16 10:37:41',
#      'updateTime': '2018-05-16 10:37:41',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 207,
#      'hour': 4972,
#      'min': 298322,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1891974': {'topicId': 1891974,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_8b0f322fb96fbc0cc96dec8190469291',
#   'day': 207,
#   'hour': 4991,
#   'min': 299477,
#   'replys': 3,
#   'topicContent': '我买过上一次众筹的 黑色款，很喜欢穿。其实，我决定这次的众筹可以对上次支持过项目的朋友来点小优惠的。这是个人的一点点建议。',
#   'createTime': '2018-05-15 15:23:01',
#   'updateTime': '2018-05-21 14:02:59',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_53b7ac945904a',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2059093,
#      'pin': '_43450b750627540377c3e36e90878543881c359206d041af489a82d99c7c3efb',
#      'topicId': 1891974,
#      'parentId': 0,
#      'content': '你上次买的是什么颜色，枣红色和天蓝我在纠结。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-21 14:02:59',
#      'updateTime': '2018-05-21 14:02:59',
#      'nicknameShow': 'jd_8510032422c8d',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3835313030333234323263386431353234383935393931303738_mid.jpg',
#      'day': 202,
#      'hour': 4848,
#      'min': 290917,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2052259,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1891974,
#      'parentId': 2051789,
#      'content': '众筹首页有个领券中心，满99-5.199-10',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-16 10:19:21',
#      'updateTime': '2018-05-16 10:19:21',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 207,
#      'hour': 4972,
#      'min': 298341,
#      'levelId': 0,
#      'repnicknameShow': 'jd_53b7ac945904a',
#      'parentPin': 'nono20090803',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2051789,
#      'pin': '_8b0f322fb96fbc0cc96dec8190469291',
#      'topicId': 1891974,
#      'parentId': 0,
#      'content': '在领券中心没有找到优惠券。哪里能领？',
#      'replys': 1,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-15 18:31:37',
#      'updateTime': '2018-05-16 10:19:21',
#      'nicknameShow': 'jd_53b7ac945904a',
#      'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#      'day': 207,
#      'hour': 4988,
#      'min': 299288,
#      'levelId': 3,
#      'parentPin': 'nono20090803',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 2,
#    'allCount': 4},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1891706': {'topicId': 1891706,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_43450b750627540377c3e36e90878543881c359206d041af489a82d99c7c3efb',
#   'day': 208,
#   'hour': 4995,
#   'min': 299736,
#   'replys': 1,
#   'topicContent': '在纠结枣红色和天蓝色[大哭]',
#   'createTime': '2018-05-15 11:03:38',
#   'updateTime': '2018-05-15 11:42:07',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_8510032422c8d',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3835313030333234323263386431353234383935393931303738_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2059091,
#      'pin': '_43450b750627540377c3e36e90878543881c359206d041af489a82d99c7c3efb',
#      'topicId': 1891706,
#      'parentId': 2050968,
#      'content': '退的话也很麻烦啊 还要寄来寄去；',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-21 14:02:12',
#      'updateTime': '2018-05-21 14:02:12',
#      'nicknameShow': 'jd_8510032422c8d',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3835313030333234323263386431353234383935393931303738_mid.jpg',
#      'day': 202,
#      'hour': 4848,
#      'min': 290918,
#      'levelId': 0,
#      'repnicknameShow': '粤脉电商视觉设计',
#      'parentPin': '粤脉电商视觉设计',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2050968,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1891706,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，每款鞋子的颜色搭配都是有它的味道，实在对于选择困难症的朋友，可以全买，嘻嘻。不过还是可以解决的，亲可以先下单其中颜色，待收到后，不喜欢，是可以进行换颜色哒',
#      'replys': 1,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-15 11:42:07',
#      'updateTime': '2018-05-21 14:02:12',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 208,
#      'hour': 4994,
#      'min': 299698,
#      'levelId': 0,
#      'parentPin': '粤脉电商视觉设计',
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 2},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1890593': {'topicId': 1890593,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_ce4451c2dca9841db8de5cf62b95afb9881c359206d041af489a82d99c7c3efb',
#   'day': 209,
#   'hour': 5019,
#   'min': 301161,
#   'replys': 1,
#   'topicContent': '已经下单，希望我爸爸会喜欢[偷笑]',
#   'createTime': '2018-05-14 11:19:14',
#   'updateTime': '2018-05-14 11:42:12',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '美美--哒',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3562643664663032363332646431353330353230313136383739_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2049498,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1890593,
#      'parentId': 0,
#      'content': '感谢支持陈老师原创作品，不挑年龄，满满怀旧感，更是满满的爱[太阳]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-14 11:42:12',
#      'updateTime': '2018-05-14 11:42:12',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 209,
#      'hour': 5018,
#      'min': 301138,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1888571': {'topicId': 1888571,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_f435d2fa922921ef633204878f682473881c359206d041af489a82d99c7c3efb',
#   'day': 210,
#   'hour': 5063,
#   'min': 303837,
#   'replys': 1,
#   'topicContent': '8公分，走在街上会不会太亮点，虽然长的不高，但是也不想让人太注意',
#   'createTime': '2018-05-12 14:42:50',
#   'updateTime': '2018-05-12 15:01:12',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'kim_大忙人',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3136386136396263636232353831353233313734363933393133_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2047371,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1888571,
#      'parentId': 0,
#      'content': '这么兄弟，不知道你多高，增高8cm，秒变大长腿，气质都不一样了哦。如果觉得不喜欢，可以单拍鞋子档位。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-12 15:01:12',
#      'updateTime': '2018-05-12 15:01:12',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 210,
#      'hour': 5063,
#      'min': 303819,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1888392': {'topicId': 1888392,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_1cf1413ff9c6aa23de06f3be6e234929881c359206d041af489a82d99c7c3efb',
#   'day': 211,
#   'hour': 5068,
#   'min': 304102,
#   'replys': 1,
#   'topicContent': '这个鞋底硬还是偏软？？',
#   'createTime': '2018-05-12 10:18:06',
#   'updateTime': '2018-05-12 11:26:08',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_6b1388',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3662313338386332346437633931353236303931323135303039_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2047221,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1888392,
#      'parentId': 0,
#      'content': '鞋底软硬适中。鞋底采用双组合工艺，上层为超轻发泡EVA，下层为耐磨橡胶底片，既轻便又耐磨。且不会过硬和过软，底片斜向的设计也加强鞋底弯折易起步、不易断裂。欢迎添加微信号：xhtf28 备注鞋子可以入群讨论交流哦！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-12 11:26:08',
#      'updateTime': '2018-05-12 11:26:08',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 211,
#      'hour': 5067,
#      'min': 304034,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1887683': {'topicId': 1887683,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_6fe4b6972a16f3c813fa6967cc587b75881c359206d041af489a82d99c7c3efb',
#   'day': 211,
#   'hour': 5087,
#   'min': 305222,
#   'replys': 1,
#   'topicContent': '我朋友6月生日 请问能赶的到发货吗',
#   'createTime': '2018-05-11 15:38:12',
#   'updateTime': '2018-05-11 16:04:24',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '啾咪啾咪啾1111',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3137363838663232356662636231353334383332363935363835_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2046427,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1887683,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，待项目进度达150%后，会申请提前发货，现在进度还在持续增加中，或可给您推荐第1款鞋子，可添加xhtf28 或者拨打0760-87826716 了解',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-11 16:04:24',
#      'updateTime': '2018-05-11 16:04:24',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 211,
#      'hour': 5086,
#      'min': 305196,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1887314': {'topicId': 1887314,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_cbeeea2b9e9be76494548152cf2c691a881c359206d041af489a82d99c7c3efb',
#   'day': 212,
#   'hour': 5092,
#   'min': 305546,
#   'replys': 1,
#   'topicContent': '这个是牛皮的吗 平时怎么保养',
#   'createTime': '2018-05-11 10:14:23',
#   'updateTime': '2018-05-11 10:40:36',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '135ded21',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2045920,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1887314,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，采用怀旧白雾腊感牛皮，正常一样打理，可以湿抹布抹脏处，勿在太阳下暴晒，通风阴凉处晾干',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-11 10:40:36',
#      'updateTime': '2018-05-11 10:40:36',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 212,
#      'hour': 5091,
#      'min': 305519,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1886677': {'topicId': 1886677,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_1c3069bea058f74093b18656f8d0d482881c359206d041af489a82d99c7c3efb',
#   'day': 212,
#   'hour': 5109,
#   'min': 306555,
#   'replys': 1,
#   'topicContent': '陈老师新作品？ 和上次有点差别。看起来没有上次的旧 ？ 没有做旧了吗  我比较中意上次的那款  还可以继续买吗',
#   'createTime': '2018-05-10 17:25:32',
#   'updateTime': '2018-05-10 17:37:46',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_5718bef60c608',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2045061,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1886677,
#      'parentId': 0,
#      'content': '陈老师的新作品，本次设计保留了印刷鞋底及擦脏工艺，但是不再进行做旧。即保留了设计师的个人情怀，又满足了支持者的需求。采用怀旧白雾腊感牛皮搭配增高鞋垫，更加酷炫，适合搭配夏季衣物。第1款鞋子可以购买的，可添加微信号：xhtf28  备注买鞋',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-10 17:37:46',
#      'updateTime': '2018-05-10 17:37:46',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 212,
#      'hour': 5109,
#      'min': 306542,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1885904': {'topicId': 1885904,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_918c1d2da3b00e056914bba55e08daea881c359206d041af489a82d99c7c3efb',
#   'day': 213,
#   'hour': 5116,
#   'min': 306983,
#   'replys': 1,
#   'topicContent': '会不会显得脚掌大',
#   'createTime': '2018-05-10 10:16:59',
#   'updateTime': '2018-05-10 10:48:27',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '我不高冷我高寒a',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2044321,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1885904,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，陈老师通过对东方人的脚型分析作精心的调整，不大也不小，上脚感舒适强。欢迎添加微信号：xhtf28 备注鞋子可以入群讨论交流哦！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-10 10:48:27',
#      'updateTime': '2018-05-10 10:48:27',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 213,
#      'hour': 5115,
#      'min': 306952,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1884974': {'topicId': 1884974,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_7445596fdfdcc6b2508db941254a1d7d881c359206d041af489a82d99c7c3efb',
#   'day': 213,
#   'hour': 5134,
#   'min': 308097,
#   'replys': 1,
#   'topicContent': '有实拍图吗',
#   'createTime': '2018-05-09 15:42:51',
#   'updateTime': '2018-05-09 15:56:01',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_3eeb1af79f149',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2043179,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1884974,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，模特穿的都是实物图，想了解更多，欢迎入微信群，添加微信号：xhtf28 备注鞋子将拉入群讨论交流！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-09 15:56:01',
#      'updateTime': '2018-05-09 15:56:01',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 213,
#      'hour': 5134,
#      'min': 308084,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1884582': {'topicId': 1884582,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_85d9b9a684ad7a99d758af4e218d6429881c359206d041af489a82d99c7c3efb',
#   'day': 214,
#   'hour': 5140,
#   'min': 308433,
#   'replys': 1,
#   'topicContent': '陈老师新作品 支持。上次众筹过 ，鞋子还可以，就是穿久了鞋子前面有点开胶。后面换了一双 就没有问题，希望这次能改进！！',
#   'createTime': '2018-05-09 10:06:42',
#   'updateTime': '2018-05-09 10:43:41',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'zzzgggg-',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3231613532343336333431323431353236303234393337343035_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2042738,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1884582,
#      'parentId': 0,
#      'content': '您好，感谢您的支持，首次众筹第一款原创休闲鞋，获的众多好评，从中也有许多不足，于是，进行了反思和调整。一定的改进，所以这次重回众筹平台，也还是希望给大家带来了原创新品。期待大家的支持',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-09 10:43:41',
#      'updateTime': '2018-05-09 10:43:41',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 214,
#      'hour': 5139,
#      'min': 308396,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1884324': {'topicId': 1884324,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_0da1b202340c5ada3cfe25dc41cd5a71',
#   'day': 214,
#   'hour': 5152,
#   'min': 309121,
#   'replys': 2,
#   'topicContent': '跟运动鞋码一样吗？',
#   'createTime': '2018-05-08 22:39:34',
#   'updateTime': '2018-05-09 09:46:40',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_9304861',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2042604,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1884324,
#      'parentId': 0,
#      'content': '项目组建微信群，欢迎鞋友添加微信号：xhtf28 备注鞋子将拉入群讨论交流！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-09 09:46:40',
#      'updateTime': '2018-05-09 09:46:40',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 214,
#      'hour': 5140,
#      'min': 308453,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2042588,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1884324,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，399的标配鞋垫（码数偏大半码），429的是增高鞋垫（标准码数），比如：您运动鞋穿40码，选择399档的，可选39码若选择429档位的就选择40码，您的码数是多少呢？或者给到数据，小服帮您推荐',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-09 09:43:38',
#      'updateTime': '2018-05-09 09:43:38',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 214,
#      'hour': 5140,
#      'min': 308456,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 2},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1883887': {'topicId': 1883887,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_cf7cd70182c759d7c8dc21a146c48fa6881c359206d041af489a82d99c7c3efb',
#   'day': 214,
#   'hour': 5159,
#   'min': 309548,
#   'replys': 1,
#   'topicContent': '支持了双红色和灰色，一个亮一个暗 好搭配 希望尽快发货',
#   'createTime': '2018-05-08 15:32:23',
#   'updateTime': '2018-05-08 16:17:35',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '嘟嘟宝的呆呆',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2041663,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1883887,
#      'parentId': 0,
#      'content': '鞋子上脚感舒适，色彩撞色搭配，让你个性百搭，不撞鞋，穿自己的范[可爱]，待项目达150%后，将会提前申请发货，谢谢您的支持！！欢迎添加微信号 xhtf28  备注鞋子  随时交流',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-08 16:17:35',
#      'updateTime': '2018-05-08 16:17:35',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 214,
#      'hour': 5158,
#      'min': 309502,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1883465': {'topicId': 1883465,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_e09dd75092f450a37f806d13b601071e881c359206d041af489a82d99c7c3efb',
#   'day': 215,
#   'hour': 5165,
#   'min': 309901,
#   'replys': 1,
#   'topicContent': '女款的鞋子 没有模特图吗',
#   'createTime': '2018-05-08 09:39:08',
#   'updateTime': '2018-05-08 10:09:29',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '_奋斗士',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3537366133653136643931356631353233363034313032363830_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2041021,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1883465,
#      'parentId': 0,
#      'content': '您好，感谢您的关注，女款也是为了照顾小仙女，精心设计桃心印章侧墙，暂还没有，不过上脚感舒适，欢迎下单，抢先体验',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-08 10:09:29',
#      'updateTime': '2018-05-08 10:09:29',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 215,
#      'hour': 5164,
#      'min': 309871,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1882754': {'topicId': 1882754,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_6d667f7fdb361af20666d0197cc5a89e881c359206d041af489a82d99c7c3efb',
#   'day': 215,
#   'hour': 5183,
#   'min': 310991,
#   'replys': 1,
#   'topicContent': '不会有味道吧这鞋',
#   'createTime': '2018-05-07 15:28:45',
#   'updateTime': '2018-05-07 15:38:39',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '大佬大林仔',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3734316437323235623261613631353237363439363734323134_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2040136,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1882754,
#      'parentId': 0,
#      'content': '鞋子稍微有点味道是正常的，通风处理就可以呢。因为做好之后，未经通风处理，直接包装。欢迎鞋友支持，或可入群讨论交流，添加微信 xhtf28 备注 鞋子',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-07 15:38:39',
#      'updateTime': '2018-05-07 15:38:39',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 215,
#      'hour': 5183,
#      'min': 310981,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1882425': {'topicId': 1882425,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_2b985136c26c84dd96a04078553d7c7a881c359206d041af489a82d99c7c3efb',
#   'day': 216,
#   'hour': 5187,
#   'min': 311266,
#   'replys': 1,
#   'topicContent': '看着设计风格可以，给男票买了19735311194787枣红，待收到在来买我的[偷笑]',
#   'createTime': '2018-05-07 10:54:22',
#   'updateTime': '2018-05-07 11:04:48',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_4d4c1bbbccfd7',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2039700,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1882425,
#      'parentId': 0,
#      'content': '[可爱]感谢支持。项目发货是按订单顺序依次发出的呢，小仙女可以先下单，不合适的话，我们支持退换货的呢。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-07 11:04:48',
# ...
#   'likecount': 0},
#  '1876342': {'topicId': 1876342,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_894a88cfba9fcb96d55a77cabe47bd7b',
#   'day': 223,
#   'hour': 5354,
#   'min': 321275,
#   'replys': 1,
#   'topicContent': '纠结红色和灰色中，我的天，下次直接两种颜色吧，让我好选择\n',
#   'createTime': '2018-04-30 12:05:10',
#   'updateTime': '2018-05-02 09:49:53',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '寻一朵花给你',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2034173,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1876342,
#      'parentId': 0,
#      'content': '您好，感谢您的关注和支持，每个颜色都各有配撘风采喲，也是顾虑到大家都有多选择，和市面比起来不乏味',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-02 09:49:53',
#      'updateTime': '2018-05-02 09:49:53',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 221,
#      'hour': 5308,
#      'min': 318530,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1876331': {'topicId': 1876331,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_24ff4b2c853cc4f93089c4f820ebe182881c359206d041af489a82d99c7c3efb',
#   'day': 223,
#   'hour': 5354,
#   'min': 321289,
#   'replys': 1,
#   'topicContent': '怎么有些评论跟某些商城刷好评记录那么像',
#   'createTime': '2018-04-30 11:50:57',
#   'updateTime': '2018-05-02 09:33:30',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'HXDxd',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 3,
#   'discussionPageVo': {'list': [{'discussionId': 2034109,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1876331,
#      'parentId': 0,
#      'content': '感谢您的提问。因为咱们是第二次参加众筹了呢，很多留言是之前的老客户哦，我们也很欣喜能得到大家的信任。对于前次的不足，我们反思做了调整。这次给大家带来的是休闲和运动的跨界鞋，休闲和运动的融合，多彩，独特，更出众。[玫瑰]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-02 09:33:30',
#      'updateTime': '2018-05-02 09:33:30',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 221,
#      'hour': 5309,
#      'min': 318547,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1876209': {'topicId': 1876209,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_37e28ea3a7c8744c1ca9e78cf879d4e3',
#   'day': 223,
#   'hour': 5358,
#   'min': 321507,
#   'replys': 2,
#   'topicContent': '平时皮鞋穿40码、运动鞋穿41码，这个应该买多大的？[疑问]',
#   'createTime': '2018-04-30 08:12:58',
#   'updateTime': '2018-05-02 09:34:22',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '伏特加男人',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/313330323133392d31383736373731343137393131343132353236_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2034115,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1876209,
#      'parentId': 0,
#      'content': '[太阳]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-02 09:34:22',
#      'updateTime': '2018-05-02 09:34:22',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 221,
#      'hour': 5309,
#      'min': 318546,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2032893,
#      'pin': '_154ff6f618ead5e731f5125d00deedd8',
#      'topicId': 1876209,
#      'parentId': 0,
#      'content': '谢谢你的支持!399的标配鞋垫，你拍40就好了；429的是增高鞋垫你拍41就可以。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-30 10:03:43',
#      'updateTime': '2018-04-30 10:03:43',
#      'nicknameShow': 'L***3',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/4c6f6b796368656e3139373331353130343030343435373436_mid.jpg',
#      'day': 223,
#      'hour': 5356,
#      'min': 321396,
#      'levelId': 3,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 2},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1875300': {'topicId': 1875300,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_85eaaa81652482fd67642eb9573a01c7',
#   'day': 224,
#   'hour': 5395,
#   'min': 323722,
#   'replys': 2,
#   'topicContent': '夏天穿不得捂成汗脚？',
#   'createTime': '2018-04-28 19:17:52',
#   'updateTime': '2018-05-02 11:20:25',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '-错过了',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/313837333031383335393831353235333732303031383530_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2034450,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1875300,
#      'parentId': 0,
#      'content': '鞋子采用牛皮材料，鞋口处精心采用透气尼龙网布，下层采用了上等头层猪皮加以冲孔，透气效果更佳，加上后跟部位加以稳定防拐脚设计，步伐轻松自如',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-05-02 11:20:25',
#      'updateTime': '2018-05-02 11:20:25',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 221,
#      'hour': 5307,
#      'min': 318440,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0},
#     {'discussionId': 2032898,
#      'pin': '_24afb66cfa746231340314ee3d9e5f56',
#      'topicId': 1875300,
#      'parentId': 0,
#      'content': '我其实一年四季都穿这种鞋[害羞]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-30 10:09:39',
#      'updateTime': '2018-04-30 10:09:39',
#      'nicknameShow': 'b***2',
#      'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#      'day': 223,
#      'hour': 5356,
#      'min': 321390,
#      'levelId': 4,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 2},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1875184': {'topicId': 1875184,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_7f6cad90e4fea9d07648839d410d3cd4881c359206d041af489a82d99c7c3efb',
#   'day': 224,
#   'hour': 5398,
#   'min': 323895,
#   'replys': 1,
#   'topicContent': '我平时运动鞋穿42码 ，码数准吗',
#   'createTime': '2018-04-28 16:25:37',
#   'updateTime': '2018-04-28 16:28:29',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jll云',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3665646232333133663964366431353334383232313638313837_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2031784,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1875184,
#      'parentId': 0,
#      'content': '感谢您的关注，码数标准的呢 。按您平时的码数拍下，没问题的呢。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-28 16:28:29',
#      'updateTime': '2018-04-28 16:28:29',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 224,
#      'hour': 5398,
#      'min': 323892,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1874635': {'topicId': 1874635,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_6e4554c85f0227f552fafeeddebbacd8881c359206d041af489a82d99c7c3efb',
#   'day': 225,
#   'hour': 5404,
#   'min': 324274,
#   'replys': 1,
#   'topicContent': '老客户了 之前买了蓝色，后面换了红色 ，客服态度很好，继续支持',
#   'createTime': '2018-04-28 10:06:15',
#   'updateTime': '2018-04-28 10:31:05',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '孩子有天地',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2031268,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1874635,
#      'parentId': 0,
#      'content': '您好，可先关注喔，感谢您对我们的支持和肯定，我们也会更加努力！！',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-28 10:31:05',
#      'updateTime': '2018-04-28 10:31:05',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 225,
#      'hour': 5404,
#      'min': 324249,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1874006': {'topicId': 1874006,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_24afb66cfa746231340314ee3d9e5f56',
#   'day': 225,
#   'hour': 5420,
#   'min': 325256,
#   'replys': 1,
#   'topicContent': '陈大师又有新作了？来来来，肯定支持',
#   'createTime': '2018-04-27 17:44:02',
#   'updateTime': '2018-04-27 17:49:07',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'bing520222',
#   'yunSmaImageUrl': '//i.jd.com/commons/img/no-img_mid_.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2030741,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1874006,
#      'parentId': 0,
#      'content': '感恩老客户的关注，是哒，目前正在预热中，将于4月30号，9点整正式开卖，等你喲[握手]',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-27 17:49:07',
#      'updateTime': '2018-04-27 17:49:07',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 225,
#      'hour': 5420,
#      'min': 325251,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1873991': {'topicId': 1873991,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_21e9e04422ea2ee4f10696a88b80fa08881c359206d041af489a82d99c7c3efb',
#   'day': 225,
#   'hour': 5421,
#   'min': 325270,
#   'replys': 1,
#   'topicContent': '模特图穿的是6cm的 还是加了鞋垫的',
#   'createTime': '2018-04-27 17:30:22',
#   'updateTime': '2018-04-27 17:45:17',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_158169zwr',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3466373065373239613866366431353236343530373736383631_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2030732,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1873991,
#      'parentId': 0,
#      'content': '您好，感谢您对鞋子的关注，鞋子的鞋底都是6CM,只是鞋垫分别有普通款，和加厚款，加厚款鞋底是2CM，任君选择哦',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-27 17:45:17',
#      'updateTime': '2018-04-27 17:45:17',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 225,
#      'hour': 5420,
#      'min': 325255,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1873885': {'topicId': 1873885,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_03f322a8ac5b5b84249b80fd0cfe17f2881c359206d041af489a82d99c7c3efb',
#   'day': 225,
#   'hour': 5422,
#   'min': 325345,
#   'replys': 1,
#   'topicContent': '支持！支持！上次众筹的鞋子穿上很舒服！很合脚！这次肯定的要再次支持！不知老客户是否给优惠呀？',
#   'createTime': '2018-04-27 16:15:32',
#   'updateTime': '2018-04-27 17:00:56',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': 'jd_150300kfr',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3537323836363334663236643831343631373533353732383133_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 4,
#   'discussionPageVo': {'list': [{'discussionId': 2030660,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1873885,
#      'parentId': 0,
#      'content': '感恩老客户的支持和对陈老师的设计认可。继续关注支持我们，后面会有惊喜~',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-27 17:00:56',
#      'updateTime': '2018-04-27 17:00:56',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 225,
#      'hour': 5421,
#      'min': 325299,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0},
#  '1873800': {'topicId': 1873800,
#   'key': '1000',
#   'systemId': '100010',
#   'pin': '_6fe4b6972a16f3c813fa6967cc587b75881c359206d041af489a82d99c7c3efb',
#   'day': 225,
#   'hour': 5423,
#   'min': 325382,
#   'replys': 1,
#   'topicContent': '支持支持。之前就买过一双，就喜欢你们的款式，出门不会撞鞋  现在再买一双送给朋友',
#   'createTime': '2018-04-27 15:38:37',
#   'updateTime': '2018-04-27 15:52:06',
#   'status': 0,
#   'indexStatus': 0,
#   'topicType': 0,
#   'topicSort': 0,
#   'nicknameShow': '啾咪啾咪啾1111',
#   'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/6a645f3137363838663232356662636231353334383332363935363835_mid.jpg',
#   'serviceType': 1,
#   'topicCount': 0,
#   'likeCount': 0,
#   'istread': 2,
#   'islike': 2,
#   'levelId': 0,
#   'discussionPageVo': {'list': [{'discussionId': 2030554,
#      'pin': '_28d2e66fbf9d38d656e3849ada83ba1fc23e93e87586bc24a95f34fdb48a3c36',
#      'topicId': 1873800,
#      'parentId': 0,
#      'content': '感谢老客户的大力支持，筹友的认可是我们前进的动力。',
#      'replys': 0,
#      'likeCount': 0,
#      'status': 0,
#      'createTime': '2018-04-27 15:52:06',
#      'updateTime': '2018-04-27 15:52:06',
#      'nicknameShow': '粤脉电商视觉设计',
#      'yunSmaImageUrl': '//storage.360buyimg.com/i.imageUpload/d4c1c2f6b5e7c9cccad3bef5c9e8bcc631343638303539373137383236_mid.jpg',
#      'day': 225,
#      'hour': 5422,
#      'min': 325368,
#      'levelId': 0,
#      'islike': 2,
#      'pointonCount': 0,
#      'istread': 0,
#      'reportCount': 0}],
#    'page': 1,
#    'pageCount': 1,
#    'allCount': 1},
#   'pointoncount': 0,
#   'infostatus': 10,
#   'reportCount': 0,
#   'likecount': 0}}

# %% [markdown]
# #### 1. 获取每天各个时间段内关注数、支持者数、点赞数、完成百分比和筹集金额

# %%
def recursive_print(item, lev):
    if isinstance(item, dict):
        for i, x in enumerate(item, start=1):
            print('    '*lev, x)
            recursive_print(item[x], lev=lev+1)
    else:
        return

# %%
item = s_project.find_one({"_id":'100051'})

# %%
recursive_print(item, lev=0)
# Out:
#  _id
#  状态变换时间0-1
#  状态
#  项目动态信息
#  各档动态信息
#  爬取次数
#  众筹期限
#  公司名称
#  公司地址
#  公司工作时间
#  公司电话
#  发起人名称
#  发起人链接
#  各档基础信息
#      4
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      2
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      3
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      0
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      1
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      5
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#      6
#          redound_info
#          deliver_info
#          sup_price
#          lim_num
#  所属类别
#  目标金额
#  项目名称
#  状态变换时间1-2
#  评论
#      爬取时间
#      总页数
#      总评论数
#      评论详细
#          1919544
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1879513
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1877336
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1877117
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1877022
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876920
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876826
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876723
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876573
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876529
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876404
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876382
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876355
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876329
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876327
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876322
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876313
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876231
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876224
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1876004
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#          1874648
#              topicId
#              key
#              systemId
#              pin
#              day
#              hour
#              min
#              replys
#              topicContent
#              createTime
#              updateTime
#              status
#              indexStatus
#              topicType
#              topicSort
#              nicknameShow
#              yunSmaImageUrl
#              serviceType
#              topicCount
#              likeCount
#              istread
#              islike
#              levelId
#              discussionPageVo
#                  list
#                  page
#                  pageCount
#                  allCount
#              pointoncount
#              infostatus
#              reportCount
#              likecount
#  状态变换时间2-3
#  状态变换时间3-4

# %%
for i, x in enumerate(item.keys(), start=1):
    print(i, x)
    try:
        for i in x.keys()
# Out:
# 1 _id
# 2 状态变换时间0-1
# 3 状态
# 4 项目动态信息
# 5 各档动态信息
# 6 爬取次数
# 7 众筹期限
# 8 公司名称
# 9 公司地址
# 10 公司工作时间
# 11 公司电话
# 12 发起人名称
# 13 发起人链接
# 14 各档基础信息
# 15 所属类别
# 16 目标金额
# 17 项目名称
# 18 状态变换时间1-2
# 19 评论
# 20 状态变换时间2-3
# 21 状态变换时间3-4

# %%
item['项目动态信息'][0].keys()
# Out:
# dict_keys(['更新时间', '关注数', '支持者数', '筹集金额', '创建时间', '点赞数', '爬取时间', '完成百分比'])

# %%
item['评论'].keys(), item['评论']['评论详细'].keys()
# Out:
# (dict_keys(['爬取时间', '总页数', '总评论数', '评论详细']),
#  dict_keys(['1919544', '1879513', '1877336', '1877117', '1877022', '1876920', '1876826', '1876723', '1876573', '1876529', '1876404', '1876382', '1876355', '1876329', '1876327', '1876322', '1876313', '1876231', '1876224', '1876004', '1874648']))

# %%
t_df = to_df(item)

# %%
t_df
# Out:
#                      关注数  支持者数  点赞数  完成百分比   筹集金额
# 2018-04-28 11:30:27    9     0    6    0.0      0
# 2018-04-28 13:23:59   10     0    6    0.0      0
# 2018-04-28 17:54:30   11     0    7    0.0      0
# 2018-04-28 20:19:48   12     0    8    0.0      0
# 2018-04-28 22:35:52   13     0    9    0.0      0
# ...                  ...   ...  ...    ...    ...
# 2018-06-06 19:53:58   71    30   39  106.0  53022
# 2018-06-09 14:54:48   71    30   40  106.0  53022
# 2018-06-10 10:24:54   71    30   42  106.0  53022
# 2018-06-12 11:08:38   72    30   42  106.0  53022
# 2018-06-14 23:30:50   72    31   43  107.0  53250
#
# [77 rows x 5 columns]

# %% [markdown]
# 创建时间
# ```python
# d = datetime.datetime(year=2018, month=12, day=23, hour=15, minute=11, second=11)
# d.hour, d.minute, d.second, d.weekday()
# ```

# %%
d = datetime.datetime(year=2018, month=12, day=23, hour=15, minute=11, second=11)
d.hour, d.minute, d.second, d.weekday()
# Out:
# (15, 11, 11, 6)

# %%
t_df.iloc[1].name.weekday()
# Out:
# 5

# %%
t_df.index.hour
# Out:
# Int64Index([11, 13, 17, 20, 22,  1, 13, 20,  9, 11, 12, 15,  1, 11, 12, 14, 17,
#             20, 21,  5,  7,  9, 11, 13, 15, 17, 21,  0,  9, 12, 14, 15, 16, 18,
#             23,  1,  3, 10, 13, 17, 18, 20,  0,  3,  9, 14, 21,  1, 15, 21, 15,
#             16,  1,  9, 15, 18, 22,  0, 20, 12, 23, 16, 14, 17, 21, 15, 16, 22,
#              0, 21,  8, 16, 19, 14, 10, 11, 23],
#            dtype='int64')

# %%
list(zip(t_df.index.weekday, t_df.index.hour))
# Out:
# [(5, 11),
#  (5, 13),
#  (5, 17),
#  (5, 20),
#  (5, 22),
#  (6, 1),
#  (6, 13),
#  (6, 20),
#  (0, 9),
#  (0, 11),
#  (0, 12),
#  (0, 15),
#  (1, 1),
#  (1, 11),
#  (1, 12),
#  (1, 14),
#  (1, 17),
#  (1, 20),
#  (1, 21),
#  (2, 5),
#  (2, 7),
#  (2, 9),
#  (2, 11),
#  (2, 13),
#  (2, 15),
#  (2, 17),
#  (2, 21),
#  (3, 0),
#  (3, 9),
#  (3, 12),
#  (3, 14),
#  (3, 15),
#  (3, 16),
#  (3, 18),
#  (3, 23),
#  (4, 1),
#  (4, 3),
#  (4, 10),
#  (4, 13),
#  (4, 17),
#  (4, 18),
#  (4, 20),
#  (5, 0),
#  (5, 3),
#  (5, 9),
#  (5, 14),
#  (5, 21),
#  (6, 1),
#  (6, 15),
#  (6, 21),
#  (0, 15),
#  (0, 16),
#  (1, 1),
#  (1, 9),
#  (2, 15),
#  (3, 18),
#  (3, 22),
#  (4, 0),
#  (4, 20),
#  (1, 12),
#  (2, 23),
#  (4, 16),
#  (0, 14),
#  (0, 17),
#  (0, 21),
#  (2, 15),
#  (3, 16),
#  (0, 22),
#  (1, 0),
#  (2, 21),
#  (6, 8),
#  (1, 16),
#  (2, 19),
#  (5, 14),
#  (6, 10),
#  (1, 11),
#  (3, 23)]

# %%
def getDayAdoptRange(df):
    '''
    (weekday, time_range)
    '''
    new_idx = []
    month_day = set(zip(df.index.month, df.index.day))
    for i in df.index.hour:
        if i.hour <= 6:
            
        elif i.hour <= 12:
            
        elif i.hour <= 18:
        
        else:

# %% [markdown]
# #### 2. 获取由**众筹开始时间**到**完成百分比第1次大于100**范围内的数据

# %%
def getTimeRange(df, start_t):
    x = df[df.index >= start_t]  # 开始众筹至观测结束
    y = x[x.完成百分比.values >= 100]  # 第一次达到众筹金额100%至观测结束
    d = x[:y.index[1]]  # 开始众筹至第一次达到众筹金额100%
    return d

# %% [markdown]
# 获取所有**项目成功项目**的**众筹开始时间**到**完成百分比第1次大于100**的时间间隔
#
# >其中涉及到pandas时间间隔转为秒，有两个关键的函数，首先通过`.to_pytimedelta()`将`pd.Timedelta()`转换为`datetime.datetime()`，然后利用`.total_seconds()`将`datetime.datetime()`转换为时间秒。示例：
# ```python
# >>> pd.Timestamp("2012-12-21") - pd.Timestamp("2012-12-1")
# Timedelta('20 days 00:00:00')
# >>> pd.Timedelta('5:00:00').to_pytimedelta().total_seconds()
# 18000.0
# >>> datetime.timedelta(days=1, hours=1, minutes=1).total_seconds()
# 90060.0
# ```

# %%
def getStatus(projs):  # 获取
    intv_dict, relative_intv_dict = [], []
    for i, item in enumerate(projs):
        try:
            start_t = item['状态变换时间1-2']  # 众筹开始时间
            end_t = item['状态变换时间2-3']  # 众筹成功时间
            df = to_df(item)
            t_df = getTimeRange(df, start_t)  # 开始众筹至第一次达到众筹金额100%
            time_interval = (t_df.index[-1] - t_df.index[0]).to_pytimedelta().total_seconds()  # 总时间，转化为浮点数(秒)
            tot_inteval = (end_t - start_t).total_seconds()  # 计划总时间
            intv_dict.append((item['_id'], time_interval))
            relative_intv_dict.append((item['_id'], time_interval / tot_inteval))
        except IndexError as e:
            print(i, item['_id'], e)
        except KeyError as k:
            print(i, item['_id'], k)
            
    df = pd.DataFrame({'绝对时间跨度': [x[1] for x in intv_dict], 
                       '相对时间跨度': [x[1] for x in relative_intv_dict]}, 
                       index = pd.Index([x[0] for x in intv_dict]))
    return df

# %%
projs = s_project.find({"状态": '项目成功'})
df1 = getStatus(projs)
# Out:
# 14 100128 index 1 is out of bounds for axis 0 with size 0
# 30 100214 index 1 is out of bounds for axis 0 with size 1
# 34 100224 index 1 is out of bounds for axis 0 with size 0
# 64 100361 index 1 is out of bounds for axis 0 with size 1
# 68 100375 index 1 is out of bounds for axis 0 with size 0
# 83 100461 index 1 is out of bounds for axis 0 with size 1
# 96 100551 index 1 is out of bounds for axis 0 with size 1
# 116 100684 index 1 is out of bounds for axis 0 with size 1
# 124 100702 index 1 is out of bounds for axis 0 with size 0
# 180 100981 index 1 is out of bounds for axis 0 with size 1
# 222 101150 index 1 is out of bounds for axis 0 with size 0
# 330 101685 index 1 is out of bounds for axis 0 with size 0
# 336 101724 index 1 is out of bounds for axis 0 with size 0
# 350 101812 index 1 is out of bounds for axis 0 with size 1
# 360 101857 index 1 is out of bounds for axis 0 with size 1
# 371 101886 index 1 is out of bounds for axis 0 with size 0
# 379 101964 index 1 is out of bounds for axis 0 with size 1
# 390 102009 index 1 is out of bounds for axis 0 with size 0
# 441 102273 index 1 is out of bounds for axis 0 with size 0
# 458 102369 index 1 is out of bounds for axis 0 with size 1
# 478 102451 index 1 is out of bounds for axis 0 with size 0
# 495 102543 index 1 is out of bounds for axis 0 with size 0
# 500 102569 index 1 is out of bounds for axis 0 with size 0
# 501 102574 index 1 is out of bounds for axis 0 with size 0
# 504 102589 index 1 is out of bounds for axis 0 with size 0
# 518 102655 index 1 is out of bounds for axis 0 with size 1
# 549 102815 index 1 is out of bounds for axis 0 with size 0
# 617 103154 index 1 is out of bounds for axis 0 with size 0
# 622 103172 index 1 is out of bounds for axis 0 with size 0
# 628 103205 index 1 is out of bounds for axis 0 with size 0
# 655 103374 index 1 is out of bounds for axis 0 with size 1
# 658 103381 index 1 is out of bounds for axis 0 with size 1
# 659 103382 index 1 is out of bounds for axis 0 with size 0
# 661 103385 index 1 is out of bounds for axis 0 with size 0
# 702 103602 index 1 is out of bounds for axis 0 with size 0
# 719 103707 index 1 is out of bounds for axis 0 with size 0
# 724 103742 index 1 is out of bounds for axis 0 with size 1
# 745 103939 index 1 is out of bounds for axis 0 with size 1
# 779 104094 index 1 is out of bounds for axis 0 with size 0
# 894 104922 index 1 is out of bounds for axis 0 with size 1
# 898 104937 index 1 is out of bounds for axis 0 with size 1
# 909 105025 index 1 is out of bounds for axis 0 with size 1
# 922 105127 index 1 is out of bounds for axis 0 with size 0
# 931 105166 index 1 is out of bounds for axis 0 with size 0
# 938 105214 index 1 is out of bounds for axis 0 with size 1
# 939 105217 index 1 is out of bounds for axis 0 with size 0
# 940 105224 index 1 is out of bounds for axis 0 with size 1
# 946 105280 index 1 is out of bounds for axis 0 with size 0
# 987 105585 index 1 is out of bounds for axis 0 with size 1
# 1000 105677 index 1 is out of bounds for axis 0 with size 0
# 1032 105847 index 1 is out of bounds for axis 0 with size 0
# 1034 105862 index 1 is out of bounds for axis 0 with size 0
# 1039 105902 index 1 is out of bounds for axis 0 with size 0
# 1051 106010 index 1 is out of bounds for axis 0 with size 0
# 1058 106088 index 1 is out of bounds for axis 0 with size 1
# 1065 106138 index 1 is out of bounds for axis 0 with size 1
# 1084 106328 index 1 is out of bounds for axis 0 with size 1
# 1108 106526 index 1 is out of bounds for axis 0 with size 0
# 1109 106530 index 1 is out of bounds for axis 0 with size 0
# 1112 106551 index 1 is out of bounds for axis 0 with size 0
# 1164 107040 index 1 is out of bounds for axis 0 with size 1
# 1239 107574 index 1 is out of bounds for axis 0 with size 1
# 1243 107592 index 1 is out of bounds for axis 0 with size 1
# 1255 107697 index 1 is out of bounds for axis 0 with size 1
# 1311 108078 index 1 is out of bounds for axis 0 with size 0
# 1326 108282 index 1 is out of bounds for axis 0 with size 0
# 1350 108506 index 1 is out of bounds for axis 0 with size 1
# 1351 108528 index 1 is out of bounds for axis 0 with size 0
# 1373 108713 index 1 is out of bounds for axis 0 with size 0
# 1405 108881 index 1 is out of bounds for axis 0 with size 0
# 1493 109458 index 1 is out of bounds for axis 0 with size 0
# 1517 109598 index 1 is out of bounds for axis 0 with size 0
# 1529 109688 index 1 is out of bounds for axis 0 with size 1
# 1538 109730 index 1 is out of bounds for axis 0 with size 0
# 1550 109807 index 1 is out of bounds for axis 0 with size 1
# 1611 110196 index 1 is out of bounds for axis 0 with size 1
# 1618 110238 index 1 is out of bounds for axis 0 with size 1
# 1631 110359 index 1 is out of bounds for axis 0 with size 1
# 1638 110420 index 1 is out of bounds for axis 0 with size 1
# 1645 110465 index 1 is out of bounds for axis 0 with size 0
# 1646 110500 index 1 is out of bounds for axis 0 with size 1
# 1648 110508 index 1 is out of bounds for axis 0 with size 0
# 1660 110604 index 1 is out of bounds for axis 0 with size 0
# 1675 110741 index 1 is out of bounds for axis 0 with size 1
# 1680 110835 index 1 is out of bounds for axis 0 with size 1
# 1684 110863 index 1 is out of bounds for axis 0 with size 1
# 1686 110880 index 1 is out of bounds for axis 0 with size 0
# 1760 111505 index 1 is out of bounds for axis 0 with size 1
# 1767 111566 index 1 is out of bounds for axis 0 with size 0
# 1776 111659 index 1 is out of bounds for axis 0 with size 1
# 1808 111819 index 1 is out of bounds for axis 0 with size 1
# 1814 111847 index 1 is out of bounds for axis 0 with size 1
# 1826 111905 index 1 is out of bounds for axis 0 with size 0
# 1833 111954 index 1 is out of bounds for axis 0 with size 0
# 1835 111969 index 1 is out of bounds for axis 0 with size 0
# 1848 112010 index 1 is out of bounds for axis 0 with size 1
# 1859 112106 index 1 is out of bounds for axis 0 with size 0
# 1860 112108 index 1 is out of bounds for axis 0 with size 1
# 1886 112346 index 1 is out of bounds for axis 0 with size 1
# 1960 112809 index 1 is out of bounds for axis 0 with size 0
# 1976 112982 index 1 is out of bounds for axis 0 with size 1
# 1977 112996 index 1 is out of bounds for axis 0 with size 1
# 1978 112997 index 1 is out of bounds for axis 0 with size 1
# 2014 113337 index 1 is out of bounds for axis 0 with size 1
# 2040 113528 index 1 is out of bounds for axis 0 with size 1
# 2042 113535 index 1 is out of bounds for axis 0 with size 0
# 2053 113597 index 1 is out of bounds for axis 0 with size 1
# 2118 114026 index 1 is out of bounds for axis 0 with size 1
# 2123 114057 index 1 is out of bounds for axis 0 with size 1
# 2131 114150 index 1 is out of bounds for axis 0 with size 1
# 2132 114157 index 1 is out of bounds for axis 0 with size 0
# 2134 114161 index 1 is out of bounds for axis 0 with size 1
# 2137 114178 index 1 is out of bounds for axis 0 with size 0
# 2141 114220 index 1 is out of bounds for axis 0 with size 1
# 2164 114439 index 1 is out of bounds for axis 0 with size 0
# 2168 114449 index 1 is out of bounds for axis 0 with size 0
# 2170 114460 index 1 is out of bounds for axis 0 with size 0
# 2176 114509 index 1 is out of bounds for axis 0 with size 1
# 2179 114519 index 1 is out of bounds for axis 0 with size 0
# 2193 114621 index 1 is out of bounds for axis 0 with size 1
# 2196 114638 index 1 is out of bounds for axis 0 with size 0
# 2204 114678 index 1 is out of bounds for axis 0 with size 1
# 2213 114739 index 1 is out of bounds for axis 0 with size 0
# 2221 114840 index 1 is out of bounds for axis 0 with size 1
# 2232 114925 index 1 is out of bounds for axis 0 with size 0
# 2240 114970 index 1 is out of bounds for axis 0 with size 0
# 2294 115376 index 1 is out of bounds for axis 0 with size 1
# 2317 115519 index 1 is out of bounds for axis 0 with size 0
# 2348 115686 index 1 is out of bounds for axis 0 with size 1
# 2359 115787 index 1 is out of bounds for axis 0 with size 0
# 2371 115840 index 1 is out of bounds for axis 0 with size 0
# 2380 115877 index 1 is out of bounds for axis 0 with size 1
# 2382 115895 index 1 is out of bounds for axis 0 with size 0
# 2386 115951 index 1 is out of bounds for axis 0 with size 0
# 2391 116005 index 1 is out of bounds for axis 0 with size 0
# 2400 116141 index 1 is out of bounds for axis 0 with size 1
# 2414 116231 index 1 is out of bounds for axis 0 with size 0
# 2421 116257 index 1 is out of bounds for axis 0 with size 0
# 2424 116295 index 1 is out of bounds for axis 0 with size 1
# 2427 116308 index 1 is out of bounds for axis 0 with size 1
# 2435 116335 index 1 is out of bounds for axis 0 with size 1
# 2437 116391 index 1 is out of bounds for axis 0 with size 0
# 2438 116392 index 1 is out of bounds for axis 0 with size 0
# 2441 116405 index 1 is out of bounds for axis 0 with size 0
# 2445 116429 index 1 is out of bounds for axis 0 with size 0
# 2448 116433 index 1 is out of bounds for axis 0 with size 1
# 2467 116531 index 1 is out of bounds for axis 0 with size 0
# 2502 116808 index 1 is out of bounds for axis 0 with size 0
# 2524 116994 index 1 is out of bounds for axis 0 with size 1
# 2542 117086 index 1 is out of bounds for axis 0 with size 1
# 2560 117194 index 1 is out of bounds for axis 0 with size 0
# 2580 117314 index 1 is out of bounds for axis 0 with size 1
# 2601 117458 index 1 is out of bounds for axis 0 with size 1
# 2688 118222 index 1 is out of bounds for axis 0 with size 1
# 2693 118258 index 1 is out of bounds for axis 0 with size 1
# 2700 118328 index 1 is out of bounds for axis 0 with size 0
# 2857 119967 index 1 is out of bounds for axis 0 with size 1
# 2862 119997 index 1 is out of bounds for axis 0 with size 1
# 2866 120030 index 1 is out of bounds for axis 0 with size 1
# 2950 120400 index 1 is out of bounds for axis 0 with size 1
# 2978 120558 index 1 is out of bounds for axis 0 with size 1
# 2991 120621 index 1 is out of bounds for axis 0 with size 1
# 3035 120964 index 1 is out of bounds for axis 0 with size 0
# 3047 121033 index 1 is out of bounds for axis 0 with size 0
# 3168 1817894723 index 1 is out of bounds for axis 0 with size 1
# 3231 1818630138 index 1 is out of bounds for axis 0 with size 1
# 3365 1820167421 index 1 is out of bounds for axis 0 with size 0
# 3374 1820208819 index 1 is out of bounds for axis 0 with size 1
# 3408 1820692896 index 1 is out of bounds for axis 0 with size 0
# 3478 1821980280 index 1 is out of bounds for axis 0 with size 1
# 3567 1822967364 index 1 is out of bounds for axis 0 with size 0
# 3573 1823030300 index 1 is out of bounds for axis 0 with size 0
# 3593 1823378229 index 1 is out of bounds for axis 0 with size 1
# 3649 1824131461 index 1 is out of bounds for axis 0 with size 0
# 3711 1825084140 index 1 is out of bounds for axis 0 with size 0
# 3721 1825084394 index 1 is out of bounds for axis 0 with size 0
# 3741 1825558106 index 1 is out of bounds for axis 0 with size 0
# 3762 1826154311 index 1 is out of bounds for axis 0 with size 1
# 3766 1826349182 index 1 is out of bounds for axis 0 with size 0
# 3790 1827092594 index 1 is out of bounds for axis 0 with size 0
# 3805 1827674667 index 1 is out of bounds for axis 0 with size 0
# 3997 1834738120 index 1 is out of bounds for axis 0 with size 0
# 4003 1834820799 index 1 is out of bounds for axis 0 with size 1
# 4098 94039 index 1 is out of bounds for axis 0 with size 0
# 4120 99138 '状态变换时间1-2'
# 4127 99319 index 1 is out of bounds for axis 0 with size 1
# 4139 99653 index 1 is out of bounds for axis 0 with size 1
# 4147 99802 index 1 is out of bounds for axis 0 with size 1
# 4153 99937 index 1 is out of bounds for axis 0 with size 0

# %%
df1.head()
# Out:
#            绝对时间跨度    相对时间跨度
# 100010  3776038.0  0.962224
# 100031   483075.0  0.184856
# 100034    33800.0  0.008661
# 100040  1561563.0  0.404159
# 100049    20757.0  0.007985

# %% [markdown]
# - 累积分布

# %%
num_bins = 50
fig = plt.figure(figsize=(12, 6))
title = ['absolute status', 'relative status']
xLabels = ['Time inteval', 'Relavtive time inteval']
dataset = [df1['绝对时间跨度'].values, df1['相对时间跨度'].values]

num = 0.5
for i, x in enumerate(dataset):
    ax =fig.add_subplot(2, 1, i+1)
    n, bins, patches = ax.hist(x, num_bins, color='grey', alpha=0.5, density=1, cumulative=True)
    idx = np.argwhere(n == n[n > num][0])[0][0]
    print(f"{title[i]}: {bins[idx]:.4f} pass {num} density")
    ax.set_xlabel(xLabels[i])
    ax.set_ylabel('Probability density')
    ax.axhline(num, color='green', linestyle='-', linewidth=1)
    ax.axvline(bins[idx], color='green', linestyle='-', linewidth=1)
    ax.text(bins[idx]*0.8, num + 0.05, f"{num}", color='k')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()
# Out:
# absolute status: 618039.2000 pass 0.5 density
# relative status: 0.1989 pass 0.5 density

# %% [markdown]
# - 概率密度分布

# %%
num_bins = 50
fig = plt.figure(figsize=(12, 6))
title = ['absolute status', 'relative status']
xLabels = ['Time inteval', 'Relavtive time inteval']
for i, x in enumerate(dataset):
    ax =fig.add_subplot(2, 1, i+1)
    n, bins, patches = ax.hist(x, num_bins, color='grey', alpha=0.5, density=True, stacked=True)
    accum_n = np.add.accumulate(n) / np.sum(n)
    idx = np.argwhere(accum_n >= num)[0][0]
    ax.axvline(bins[idx], color='k', linestyle='-', linewidth=1)
    ax.set_xlabel(xLabels[i])
    ax.set_ylabel('Probability density')
    #ax.axvline(bins[idx], color='red', linestyle='-', linewidth=2)
    #ax.text(bins[idx]*0.8, num + 0.05, f"{num}")

fig.tight_layout()
plt.show()

# %% [markdown]
# > 结论：
# - （1）50%的众筹成功项目只用了期望时间的19.87%达成“众筹成功”；
# - （2）40%的众筹成功项目只用了期望时间的11.93%达成“众筹成功”；
# - （3）30%的众筹成功项目只用了期望时间的7.95%达成“众筹成功”；
# - （4）20%的众筹成功项目只用了期望时间的3.98%达成“众筹成功”；
# - （5）10%的众筹成功项目只用了期望时间的0.01%达成“众筹成功”；

# %% [markdown]
# ### 探索性数据分析

# %%
oval_columns = ['状态', '众筹期限', '公司名称', '公司地址', '公司工作时间', '公司电话', '发起人名称', 
                '发起人链接', '所属类别', '目标金额', '项目名称', 
                '状态变换时间0-1', '状态变换时间1-2', '状态变换时间2-3', '状态变换时间3-4']

dyn_columns = ['筹集金额', '关注数', '支持者数', '点赞数', '完成百分比']
sts_columns = ['评论数量', '档位数量']

# %% [markdown]
# 将所有项目的信息转换为`pd.DataFrame`

# %%
def proj_info(projs, oval_columns=oval_columns, sts_columns=sts_columns, dyn_columns=dyn_columns):
    col_names = oval_columns + sts_columns + dyn_columns
    cf_dict = {x:[] for x in col_names}
    idx = []
    for item in projs:
        idx.append(item['_id'])
        for c in oval_columns:
            try:
                cf_dict[c].append(item[c])
            except Exception as e:
                print(item['_id'], e)
                cf_dict[c].append(None)
        try:
            dyn_info = item['项目动态信息'][-1]
            for c in dyn_columns:
                try:
                    cf_dict[c].append(dyn_info[c])
                except Exception as e:
                    print(item['_id'], e)
                    cf_dict[c].append(None)
        except Exception as e:
            print(item['_id'], e)

        try:
            cf_dict['评论数量'].append(item['评论']['总评论数'])
        except Exception as e:
            cf_dict['评论数量'].append(None)
            
        try:
            cf_dict['档位数量'].append(len(item['各档基础信息']))
        except Exception as e:
            cf_dict['档位数量'].append(None)

    df = pd.DataFrame(cf_dict, index=idx, columns=col_names)
    return df

# %%
projs = s_project.find({'状态':'项目成功'})

# %%
df = proj_info(projs)
# Out:
# 99138 '状态变换时间1-2'

# %%
df.count()
# Out:
# 状态           4160
# 众筹期限         4160
# 公司名称         4157
# 公司地址         4157
# 公司工作时间       4157
# 公司电话         4157
# 发起人名称        4160
# 发起人链接        4160
# 所属类别         4160
# 目标金额         4160
# 项目名称         4160
# 状态变换时间0-1    4160
# 状态变换时间1-2    4159
# 状态变换时间2-3    4160
# 状态变换时间3-4    4160
# 评论数量         4160
# 档位数量         4160
# 筹集金额         4160
# 关注数          4160
# 支持者数         4160
# 点赞数          4160
# 完成百分比        4160
# dtype: int64

# %% [markdown]
# - 和扩散时间跨度合并

# %%
dtf = pd.concat([df, df1], axis=1, join="inner", sort=True)

# %%
col = ['状态', '众筹期限', '所属类别', '目标金额', '项目名称', '筹集金额', 
       '关注数', '支持者数', '点赞数', '完成百分比', '评论数量', '档位数量', 
      '绝对时间跨度', '相对时间跨度']

# %%
dtf[col].head()
# Out:
#           状态  众筹期限  所属类别    目标金额           项目名称    筹集金额  关注数  支持者数  点赞数  \
# 100010  项目成功    45  原创设计   50000  一双街头潮流与运动的跨界鞋   50971  172   137   19
# 100031  项目成功    30  原创设计  100000   lorde时光隧道宠物笼  254904  597   496  557
# 100034  项目成功    45  原创设计   30000  华夏匠心·斗茶神器古法建盏   37109   67   303    5
# 100040  项目成功    45  原创设计  100000   iBranco上上筷礼盒  102824  160   233   38
# 100049  项目成功    30  原创设计   10000  百工潮牌---能量玛瑙手串   30122  280   220   10
#
#         完成百分比  评论数量  档位数量     绝对时间跨度    相对时间跨度
# 100010  102.0    49     3  3776038.0  0.962224
# 100031  255.0    22     3   483075.0  0.184856
# 100034  124.0     4     8    33800.0  0.008661
# 100040  103.0    38     3  1561563.0  0.404159
# 100049  301.0    60     9    20757.0  0.007985

# %%
dtf.count()
# Out:
# 状态           3971
# 众筹期限         3971
# 公司名称         3971
# 公司地址         3971
# 公司工作时间       3969
# 公司电话         3969
# 发起人名称        3971
# 发起人链接        3971
# 所属类别         3971
# 目标金额         3971
# 项目名称         3971
# 状态变换时间0-1    3971
# 状态变换时间1-2    3971
# 状态变换时间2-3    3971
# 状态变换时间3-4    3971
# 评论数量         3971
# 档位数量         3971
# 筹集金额         3971
# 关注数          3971
# 支持者数         3971
# 点赞数          3971
# 完成百分比        3971
# 绝对时间跨度       3971
# 相对时间跨度       3971
# dtype: int64

# %% [markdown]
# - 相关系数

# %%
col_name = ['关注数', '支持者数', '评论数量', '档位数量', '绝对时间跨度', '相对时间跨度', '完成百分比']
dtf[col_name].corr()
# Out:
#              关注数      支持者数      评论数量      档位数量    绝对时间跨度    相对时间跨度     完成百分比
# 关注数     1.000000  0.506447  0.283057  0.079122 -0.154259 -0.171722  0.024425
# 支持者数    0.506447  1.000000  0.447036  0.081020 -0.164870 -0.194276  0.053552
# 评论数量    0.283057  0.447036  1.000000  0.178881 -0.159607 -0.170464  0.036998
# 档位数量    0.079122  0.081020  0.178881  1.000000 -0.145688 -0.137782 -0.021425
# 绝对时间跨度 -0.154259 -0.164870 -0.159607 -0.145688  1.000000  0.930907 -0.078639
# 相对时间跨度 -0.171722 -0.194276 -0.170464 -0.137782  0.930907  1.000000 -0.083468
# 完成百分比   0.024425  0.053552  0.036998 -0.021425 -0.078639 -0.083468  1.000000

# %%
dtf.describe()
# Out:
#               众筹期限          目标金额         评论数量         档位数量          筹集金额  \
# count  3971.000000  3.971000e+03  3971.000000  3971.000000  3.971000e+03
# mean     36.520524  6.014994e+04    63.481743     2.138756  2.609889e+05
# std       9.971712  9.740485e+04   114.667744     3.010751  1.341861e+06
# min      10.000000  5.000000e+00     0.000000     0.000000  1.421000e+03
# 25%      30.000000  1.000000e+04    14.000000     0.000000  3.010300e+04
# 50%      30.000000  5.000000e+04    34.000000     0.000000  6.447000e+04
# 75%      45.000000  1.000000e+05    71.000000     5.000000  1.515185e+05
# max     180.000000  3.000000e+06  1893.000000    21.000000  4.018386e+07
#
#                 关注数          支持者数           点赞数          完成百分比        绝对时间跨度  \
# count   3971.000000   3971.000000   3971.000000    3971.000000  3.971000e+03
# mean     700.793251    802.365147    414.982120     713.841853  1.054560e+06
# std     1515.810327   2218.774933   1193.468392    6490.283611  1.034076e+06
# min        0.000000      1.000000      0.000000      27.000000  2.420000e+02
# 25%       78.000000    103.000000      9.000000     114.000000  1.942975e+05
# 50%      210.000000    228.000000     30.000000     171.000000  6.668218e+05
# 75%     1054.500000    599.000000    319.500000     337.500000  1.792658e+06
# max    31909.000000  55230.000000  28972.000000  231800.000000  5.148552e+06
#
#             相对时间跨度
# count  3971.000000
# mean      0.338109
# std       0.319325
# min       0.000094
# 25%       0.058486
# 50%       0.209944
# 75%       0.593997
# max       0.994265

# %% [markdown]
# - 各类别信息

# %%
cat_dict = {name: group for name, group in dtf.groupby('所属类别')}

# %%
for name, group in sorted(list(cat_dict.items()), 
                        key=lambda x: len(x[1]), 
                        reverse=1):
    print(name, len(group))
# Out:
# 原创设计 436
# 食品 409
# 公益 405
# 文化传承 330
# 智能家居 190
# 数码周边 159
# 健康医疗 123
# 车品 119
# 健康生活 114
# 设计家居 100
# 可穿戴 93
# 品质家居 66
# 个人护理 62
# 时尚科技 57
# 专属定制 53
# 体育 45
# 手机周边 32
# 母婴 25
# 健身装备 23
# 其它 23
# 生活电器 23
# 情趣用品 18
# 图书 17
# 空气净化 14
# 游戏 10
# 手机 8
# 水健康 8
# 冰洗卫浴 5
# 旅游 4
# 检测设备 4
# 大家电 2
# 安防 2
# 手环 2
# 音乐 2
# 扶贫 1
# 活动 1
# 电脑 1
# 美妆 1

# %% [markdown]
# - 简单线性回归

# %%
import statsmodels.formula.api as smf

# %%
mod = smf.ols(formula='相对时间跨度~关注数+支持者数+评论数量-1', data=dtf)
res = mod.fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 相对时间跨度   R-squared (uncentered):                   0.077
# Model:                            OLS   Adj. R-squared (uncentered):              0.076
# Method:                 Least Squares   F-statistic:                              110.3
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):                    1.39e-68
# Time:                        08:55:10   Log-Likelihood:                         -2435.3
# No. Observations:                3971   AIC:                                      4877.
# Df Residuals:                    3968   BIC:                                      4895.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 关注数         4.148e-05   5.27e-06      7.865      0.000    3.11e-05    5.18e-05
# 支持者数        -1.73e-05   3.99e-06     -4.340      0.000   -2.51e-05   -9.48e-06
# 评论数量           0.0008    6.5e-05     12.716      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       42.028   Durbin-Watson:                   1.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.108
# Skew:                           0.254   Prob(JB):                     4.36e-10
# Kurtosis:                       3.057   Cond. No.                         24.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod = smf.ols(formula='完成百分比~关注数+支持者数+评论数量-1', data=dtf)
res = mod.fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  完成百分比   R-squared (uncentered):                   0.010
# Model:                            OLS   Adj. R-squared (uncentered):              0.009
# Method:                 Least Squares   F-statistic:                              13.22
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):                    1.39e-08
# Time:                        08:55:37   Log-Likelihood:                         -40496.
# No. Observations:                3971   AIC:                                  8.100e+04
# Df Residuals:                    3968   BIC:                                  8.102e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 关注数            0.0674      0.077      0.879      0.380      -0.083       0.218
# 支持者数           0.1388      0.058      2.395      0.017       0.025       0.252
# 评论数量           2.5434      0.944      2.693      0.007       0.692       4.395
# ==============================================================================
# Omnibus:                     9818.906   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        103490288.138
# Skew:                          26.336   Prob(JB):                         0.00
# Kurtosis:                     792.115   Cond. No.                         24.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
res.params
# Out:
# 关注数     0.067388
# 支持者数    0.138773
# 评论数量    2.543402
# dtype: float64

# %% [markdown]
# - 项目金额完成百分比统计信息

# %%
percent = dtf[col]['完成百分比'].values

# %%
np.mean(percent),np.std(percent)
# Out:
# (713.8418534374213, 6489.466349365152)

# %%
np.max(percent), np.min(percent)
# Out:
# (231800.0, 27.0)

# %%
num_bins = 200
fig = plt.figure(figsize=(12, 6))
title = ['absolute status', 'relative status']
xLabels = ['Time inteval', 'Relavtive time inteval']

ax =fig.add_subplot(1, 1, 1)
n, bins, patches = ax.hist(percent/100, num_bins, color='grey', alpha=0.5, density=1)
ax.set_xlabel('')
ax.set_ylabel('Probability density')

fig.tight_layout()
plt.show()
